# %%
import gym
env = gym.make('MountainCar-v0')
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7h/6jgdtfq939gc0fkr1959w_3w0000gn/T/ipykernel_2323/2164186100.py in <module>
# ----> 1 import gym
#       2 env = gym.make('MountainCar-v0')
#       3 env.reset()
#       4 for _ in range(1000):
#       5     env.render()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gym/__init__.py in <module>
#      12 from gym import logger
#      13 from gym import vector
# ---> 14 from gym import wrappers
#      15
#      16 __all__ = ["Env", "Space", "Wrapper", "make", "spec", "register"]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gym/wrappers/__init__.py in <module>
#       3 from gym.wrappers.time_limit import TimeLimit
#       4 from gym.wrappers.filter_observation import FilterObservation
# ----> 5 from gym.wrappers.atari_preprocessing import AtariPreprocessing
#       6 from gym.wrappers.time_aware_observation import TimeAwareObservation
#       7 from gym.wrappers.rescale_action import RescaleAction
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gym/wrappers/atari_preprocessing.py in <module>
#       5 from gym.wrappers import TimeLimit
#       6 try:
# ----> 7     import cv2
#       8 except ImportError:
#       9     cv2 = None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/cv2/__init__.py in <module>
#       3 import sys
#       4
# ----> 5 from .cv2 import *
#       6 from .data import *
#       7
#
# KeyboardInterrupt:

# %%
import gym
env = gym.make('CartPole-v0')

# %%
env.action_space
# Out:
# Discrete(2)

# %%
gym.Space
# Out:
# gym.spaces.space.Space

# %%
import numpy as np
from gym import spaces as S
b = S.Box(low=-np.inf, high=np.inf, shape=(12,))
b.sample()[4]
# Out:
# -0.05641373

# %%
import gym
env = gym.make('CartPole-v0')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# 2021-07-31 17:23:25.315 Python[2323:58394] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/7h/6jgdtfq939gc0fkr1959w_3w0000gn/T/org.python.python.savedState
# [ 0.03117583 -0.03388213 -0.02941372 -0.01123784]
# {}
# [ 0.03049819  0.16164904 -0.02963848 -0.31305411]
# {}
# [ 0.03373117 -0.03303843 -0.03589956 -0.02986361]
# {}
# [ 0.0330704   0.16257946 -0.03649684 -0.33365359]
# {}
# [ 0.03632199  0.35820135 -0.04316991 -0.6376187 ]
# {}
# [ 0.04348602  0.55389786 -0.05592228 -0.94357799]
# {}
# [ 0.05456397  0.74972684 -0.07479384 -1.25329484]
# {}
# [ 0.06955851  0.94572286 -0.09985974 -1.56843583]
# {}
# [ 0.08847297  0.75192521 -0.13122846 -1.30849756]
# {}
# [ 0.10351147  0.55868726 -0.15739841 -1.05960338]
# {}
# [ 0.11468522  0.36596032 -0.17859047 -0.82017089]
# {}
# [ 0.12200442  0.17367292 -0.19499389 -0.5885542 ]
# {}
# [ 0.12547788 -0.0182611  -0.20676498 -0.36307481]
# {}
# Episode finished after 13 timesteps
# [-0.00475669 -0.01684158  0.04230506  0.01733698]
# {}
# [-0.00509352 -0.2125439   0.0426518   0.32306179]
# {}
# [-0.0093444  -0.40824642  0.04911304  0.62888443]
# {}
# [-0.01750933 -0.21384303  0.06169073  0.35206439]
# {}
# [-0.02178619 -0.01965012  0.06873202  0.07945471]
# {}
# [-0.02217919  0.17442266  0.07032111 -0.19077581]
# {}
# [-0.01869074  0.36847182  0.06650559 -0.46047279]
# {}
# [-0.0113213   0.56259381  0.05729614 -0.73147382]
# {}
# [-6.94230275e-05  7.56879119e-01  4.26666615e-02 -1.00558772e+00]
# {}
# [ 0.01506816  0.95140609  0.02255491 -1.28457243]
# {}
# [ 0.03409628  1.14623374 -0.00313654 -1.57010899]
# {}
# [ 0.05702096  0.95114937 -0.03453872 -1.27840601]
# {}
# [ 0.07604394  1.14669414 -0.06010684 -1.5817006 ]
# {}
# [ 0.09897783  0.95233683 -0.09174085 -1.30835189]
# {}
# [ 0.11802456  0.75848926 -0.11790789 -1.04573729]
# {}
# [ 0.13319435  0.95496211 -0.13882264 -1.37298503]
# {}
# [ 0.15229359  0.76182172 -0.16628234 -1.12674446]
# {}
# [ 0.16753002  0.56922186 -0.18881723 -0.89049152]
# {}
# [ 0.17891446  0.76633449 -0.20662706 -1.23608852]
# {}
# Episode finished after 19 timesteps
# [ 0.02198959  0.02233569 -0.02378918  0.04733356]
# {}
# [ 0.02243631 -0.1724372  -0.02284251  0.33241688]
# {}
# [ 0.01898756 -0.3672267  -0.01619417  0.61780978]
# {}
# [ 0.01164303 -0.17188232 -0.00383798  0.32007075]
# {}
# [ 0.00820538 -0.3669494   0.00256344  0.61154086]
# {}
# [ 0.00086639 -0.17186337  0.01479425  0.31966643]
# {}
# [-0.00257087 -0.36719286  0.02118758  0.61697795]
# {}
# [-0.00991473 -0.17237321  0.03352714  0.33104275]
# {}
# [-0.0133622  -0.36795597  0.040148    0.63410714]
# {}
# [-0.02072132 -0.56361427  0.05283014  0.93915844]
# {}
# [-0.0319936  -0.75940709  0.07161331  1.24796275]
# {}
# [-0.04718174 -0.56527267  0.09657256  0.97854384]
# {}
# [-0.0584872  -0.76154742  0.11614344  1.29993237]
# {}
# [-0.07371814 -0.95793609  0.14214209  1.62660019]
# {}
# [-0.09287687 -0.76474333  0.17467409  1.38138283]
# {}
# [-0.10817173 -0.96156123  0.20230175  1.72321072]
# {}
# Episode finished after 16 timesteps
# [-0.00549714  0.01840211  0.02181949  0.04618678]
# {}
# [-0.0051291   0.2132045   0.02274322 -0.23953282]
# {}
# [-0.00086501  0.4079943   0.01795257 -0.52495602]
# {}
# [ 0.00729488  0.21262437  0.00745345 -0.22667058]
# {}
# [0.01154736 0.01739669 0.00292004 0.06835409]
# {}
# [ 0.0118953  -0.177767    0.00428712  0.36195687]
# {}
# [0.00833996 0.01729375 0.01152625 0.07062884]
# {}
# [ 0.00868583 -0.17799153  0.01293883  0.36692595]
# {}
# [0.005126   0.01694419 0.02027735 0.07835075]
# {}
# [ 0.00546488  0.21176968  0.02184437 -0.20786626]
# {}
# [ 0.00970028  0.40657257  0.01768704 -0.49357915]
# {}
# [ 0.01783173  0.60144066  0.00781546 -0.78063585]
# {}
# [ 0.02986054  0.40621214 -0.00779726 -0.4855043 ]
# {}
# [ 0.03798479  0.21120109 -0.01750735 -0.19528898]
# {}
# [ 0.04220881  0.01633388 -0.02141313  0.09182013]
# {}
# [ 0.04253549 -0.17847471 -0.01957672  0.37767105]
# {}
# [ 0.03896599 -0.37331323 -0.0120233   0.66411765]
# {}
# [ 0.03149973 -0.17802611  0.00125905  0.36767336]
# {}
# [ 0.0279392  -0.37316592  0.00861252  0.66075302]
# {}
# [ 0.02047589 -0.56840666  0.02182758  0.95613531]
# {}
# [ 0.00910775 -0.76381527  0.04095028  1.2555952 ]
# {}
# [-0.00616855 -0.9594369   0.06606219  1.56081766]
# {}
# [-0.02535729 -1.15528417  0.09727854  1.87335593]
# {}
# [-0.04846297 -0.96134987  0.13474566  1.61238462]
# {}
# [-0.06768997 -0.76805158  0.16699335  1.36456086]
# {}
# [-0.083051   -0.57536786  0.19428457  1.12842409]
# {}
# Episode finished after 26 timesteps
# [-2.77884139e-02 -4.40514510e-02  4.57234269e-05 -5.15126617e-03]
# {}
# [-2.86694429e-02 -2.39174058e-01 -5.73018966e-05  2.87546087e-01]
# {}
# [-0.03345292 -0.43429519  0.00569362  0.58021094]
# {}
# [-0.04213883 -0.23925349  0.01729784  0.28932704]
# {}
# [-0.0469239  -0.43461778  0.02308438  0.58741494]
# {}
# [-0.05561625 -0.63005528  0.03483268  0.8872793 ]
# {}
# [-0.06821736 -0.82563228  0.05257826  1.19070558]
# {}
# [-0.08473    -0.63122958  0.07639238  0.91495539]
# {}
# [-0.0973546  -0.4372193   0.09469148  0.64722624]
# {}
# [-0.10609898 -0.24353532  0.10763601  0.38579949]
# {}
# [-0.11096969 -0.05009288  0.115352    0.12889898]
# {}
# [-0.11197155 -0.24666211  0.11792998  0.45563165]
# {}
# [-0.11690479 -0.44323677  0.12704261  0.78303673]
# {}
# [-0.12576952 -0.63985441  0.14270335  1.1128365 ]
# {}
# [-0.13856661 -0.83653236  0.16496008  1.44666715]
# {}
# [-0.15529726 -1.03325395  0.19389342  1.78602237]
# {}
# Episode finished after 16 timesteps
# [-0.00701737  0.04441322 -0.01372416 -0.03465359]
# {}
# [-0.00612911 -0.15050926 -0.01441723  0.25366782]
# {}
# [-0.00913929  0.04481555 -0.00934387 -0.04352746]
# {}
# [-0.00824298 -0.15017117 -0.01021442  0.2461928 ]
# {}
# [-0.01124641 -0.34514576 -0.00529056  0.53563644]
# {}
# [-0.01814932 -0.54019292  0.00542216  0.82664766]
# {}
# [-0.02895318 -0.34514553  0.02195512  0.53567499]
# {}
# [-0.03585609 -0.15033907  0.03266862  0.24999001]
# {}
# [-0.03886287 -0.34591195  0.03766842  0.55279566]
# {}
# [-0.04578111 -0.15133867  0.04872433  0.27221468]
# {}
# [-0.04880788  0.04305539  0.05416863 -0.00471106]
# {}
# [-0.04794678 -0.15279989  0.0540744   0.30455874]
# {}
# [-0.05100277 -0.34864909  0.06016558  0.61379326]
# {}
# [-0.05797576 -0.54455789  0.07244144  0.92480276]
# {}
# [-0.06886691 -0.7405796   0.0909375   1.23934331]
# {}
# [-0.08367851 -0.54673553  0.11572437  0.97647744]
# {}
# [-0.09461322 -0.74320329  0.13525391  1.30315501]
# {}
# [-0.10947728 -0.5500311   0.16131701  1.05568657]
# {}
# [-0.1204779  -0.74688042  0.18243075  1.39434866]
# {}
# Episode finished after 19 timesteps
# [ 0.04360858  0.02219399 -0.04663171 -0.00679506]
# {}
# [ 0.04405246 -0.17222925 -0.04676761  0.27081803]
# {}
# [ 0.04060787 -0.36665372 -0.04135125  0.54839118]
# {}
# [ 0.0332748  -0.170976   -0.03038343  0.24297171]
# {}
# [ 0.02985528  0.02456647 -0.025524   -0.05913797]
# {}
# [ 0.03034661 -0.17018039 -0.02670676  0.22538393]
# {}
# [ 0.026943   -0.36491068 -0.02219908  0.50952434]
# {}
# [ 0.01964479 -0.16948313 -0.01200859  0.20992926]
# {}
# [ 0.01625513 -0.36443134 -0.00781     0.49880004]
# {}
# [ 0.0089665  -0.16920015  0.002166    0.20366608]
# {}
# [ 0.0055825  -0.36435301  0.00623932  0.49703148]
# {}
# [-0.00170456 -0.16931959  0.01617995  0.20632139]
# {}
# [-0.00509096  0.0255673   0.02030638 -0.08121398]
# {}
# [-0.00457961  0.22039236  0.0186821  -0.36742166]
# {}
# [-1.71762883e-04  4.15243928e-01  1.13336626e-02 -6.54155790e-01]
# {}
# [ 0.00813312  0.21996602 -0.00174945 -0.35792571]
# {}
# [ 0.01253244  0.41511279 -0.00890797 -0.65115977]
# {}
# [ 0.02083469  0.22011604 -0.02193116 -0.36129514]
# {}
# [ 0.02523701  0.41554274 -0.02915707 -0.66081195]
# {}
# [ 0.03354787  0.61105803 -0.0423733  -0.9625312 ]
# {}
# [ 0.04576903  0.4165303  -0.06162393 -0.68345555]
# {}
# [ 0.05409963  0.61245136 -0.07529304 -0.99488527]
# {}
# [ 0.06634866  0.41841284 -0.09519075 -0.72676736]
# {}
# [ 0.07471692  0.614713   -0.10972609 -1.04782839]
# {}
# [ 0.08701118  0.81110636 -0.13068266 -1.37284158]
# {}
# [ 0.10323331  1.00759748 -0.15813949 -1.70337653]
# {}
# [ 0.12338526  0.81461028 -0.19220702 -1.46380734]
# {}
# Episode finished after 27 timesteps
# [-0.01317767  0.03823036 -0.03523981  0.03716547]
# {}
# [-0.01241307 -0.15636899 -0.0344965   0.31852491]
# {}
# [-0.01554045  0.03922686 -0.02812601  0.01516573]
# {}
# [-0.01475591  0.23474065 -0.02782269 -0.28625692]
# {}
# [-0.0100611   0.43024812 -0.03354783 -0.58758343]
# {}
# [-0.00145613  0.23561165 -0.0452995  -0.30565423]
# {}
# [ 0.0032561   0.43134888 -0.05141258 -0.61227237]
# {}
# [ 0.01188308  0.62715023 -0.06365803 -0.92069496]
# {}
# [ 0.02442608  0.82307204 -0.08207193 -1.23268525]
# {}
# [ 0.04088752  1.01914779 -0.10672564 -1.54991095]
# {}
# [ 0.06127048  1.21537618 -0.13772385 -1.87389659]
# {}
# [ 0.085578    1.41170731 -0.17520179 -2.20596764]
# {}
# Episode finished after 12 timesteps
# [-0.04580037  0.04939305 -0.01394837  0.02205303]
# {}
# [-0.04481251 -0.14552612 -0.01350731  0.31030265]
# {}
# [-0.04772303  0.04978565 -0.00730126  0.0133907 ]
# {}
# [-0.04672732 -0.14523084 -0.00703344  0.30376108]
# {}
# [-0.04963193 -0.34025185 -0.00095822  0.59421755]
# {}
# [-0.05643697 -0.53536038  0.01092613  0.88659849]
# {}
# [-0.06714418 -0.34038843  0.0286581   0.59737025]
# {}
# [-0.07395195 -0.53589944  0.04060551  0.89894066]
# {}
# [-0.08466994 -0.7315475   0.05858432  1.20410558]
# {}
# [-0.09930089 -0.53722973  0.08266643  0.93034293]
# {}
# [-0.11004548 -0.34331496  0.10127329  0.66474033]
# {}
# [-0.11691178 -0.1497367   0.1145681   0.40558419]
# {}
# [-0.11990651 -0.34628109  0.12267978  0.73207742]
# {}
# [-0.12683214 -0.1530487   0.13732133  0.4803847 ]
# {}
# [-0.12989311 -0.34981476  0.14692902  0.81300104]
# {}
# [-0.13688941 -0.15697781  0.16318904  0.56990411]
# {}
# [-0.14002896 -0.35396686  0.17458713  0.90922688]
# {}
# [-0.1471083  -0.16158281  0.19277166  0.67610589]
# {}
# [-0.15033995  0.03041232  0.20629378  0.44977219]
# {}
# Episode finished after 19 timesteps
# [-0.03397491 -0.02367712  0.02489698 -0.0193199 ]
# {}
# [-0.03444845  0.17107909  0.02451058 -0.30404474]
# {}
# [-0.03102687 -0.02438343  0.01842969 -0.00373362]
# {}
# [-0.03151454 -0.21976478  0.01835502  0.29470665]
# {}
# [-0.03590984 -0.02490925  0.02424915  0.00786867]
# {}
# [-0.03640802 -0.22037043  0.02440652  0.30810278]
# {}
# [-0.04081543 -0.41583149  0.03056858  0.60838186]
# {}
# [-0.04913206 -0.22114993  0.04273621  0.32548171]
# {}
# [-0.05355506 -0.02666169  0.04924585  0.04657635]
# {}
# [-0.05408829 -0.22245394  0.05017738  0.3543811 ]
# {}
# [-0.05853737 -0.41825212  0.057265    0.66245467]
# {}
# [-0.06690241 -0.61412208  0.07051409  0.97260473]
# {}
# [-0.07918486 -0.81011575  0.08996619  1.2865786 ]
# {}
# [-0.09538717 -1.00626006  0.11569776  1.60601957]
# {}
# [-0.11551237 -1.20254463  0.14781815  1.93241733]
# {}
# [-0.13956326 -1.39890753  0.1864665   2.26705006]
# {}
# Episode finished after 16 timesteps
# [-9.74654814e-03  3.69098575e-02  2.55623994e-02  4.55917482e-05]
# {}
# [-0.00900835 -0.15856919  0.02556331  0.3006829 ]
# {}
# [-0.01217973  0.03617925  0.03157697  0.01617048]
# {}
# [-0.01145615 -0.15938099  0.03190038  0.31864669]
# {}
# [-0.01464377 -0.35494241  0.03827331  0.6212167 ]
# {}
# [-0.02174262 -0.55057736  0.05069765  0.92570382]
# {}
# [-0.03275417 -0.74634599  0.06921172  1.23387819]
# {}
# [-0.04768108 -0.5521787   0.09388929  0.96365656]
# {}
# [-0.05872466 -0.74842811  0.11316242  1.28429706]
# {}
# [-0.07369322 -0.94479423  0.13884836  1.61016109]
# {}
# [-0.09258911 -0.75155884  0.17105158  1.36378792]
# {}
# [-0.10762028 -0.55894194  0.19832734  1.12912334]
# {}
# Episode finished after 12 timesteps
# [-0.0205062  -0.04807711  0.00042187  0.0119201 ]
# {}
# [-0.02146774 -0.24320511  0.00066028  0.3047361 ]
# {}
# [-0.02633184 -0.04809257  0.006755    0.01226148]
# {}
# [-0.0272937   0.14693185  0.00700023 -0.27828253]
# {}
# [-0.02435506  0.34195324  0.00143458 -0.5687494 ]
# {}
# [-0.01751599  0.53705505 -0.00994041 -0.86098003]
# {}
# [-0.00677489  0.34206987 -0.02716001 -0.57143915]
# {}
# [ 6.65049232e-05  1.47339094e-01 -3.85887946e-02 -2.87434778e-01]
# {}
# [ 0.00301329  0.3429895  -0.04433749 -0.5920342 ]
# {}
# [ 0.00987308  0.14851538 -0.05617817 -0.31364064]
# {}
# [ 0.01284338  0.34439074 -0.06245099 -0.62349787]
# {}
# [ 0.0197312   0.15019378 -0.07492094 -0.35111894]
# {}
# [ 0.02273507  0.34629679 -0.08194332 -0.66645444]
# {}
# [ 0.02966101  0.15240435 -0.09527241 -0.40065607]
# {}
# [ 0.0327091   0.3487395  -0.10328553 -0.72179096]
# {}
# [ 0.03968389  0.54512705 -0.11772135 -1.04511438]
# {}
# [ 0.05058643  0.35174787 -0.13862364 -0.79158342]
# {}
# [ 0.05762139  0.15877374 -0.15445531 -0.54552394]
# {}
# [ 0.06079686  0.35569007 -0.16536579 -0.88261166]
# {}
# [ 0.06791066  0.16315335 -0.18301802 -0.64614267]
# {}
# [ 0.07117373  0.36028991 -0.19594087 -0.99041632]
# {}
# Episode finished after 21 timesteps
# [-0.03755219 -0.02686021 -0.04999523  0.04365554]
# {}
# [-0.0380894  -0.22123092 -0.04912212  0.32015484]
# {}
# [-0.04251401 -0.02544507 -0.04271903  0.01239421]
# {}
# [-0.04302292  0.17026266 -0.04247114 -0.29345514]
# {}
# [-0.03961766  0.3659636  -0.04834024 -0.5992246 ]
# {}
# [-0.03229839  0.56172737 -0.06032474 -0.90673372]
# {}
# [-0.02106384  0.75761191 -0.07845941 -1.21775079]
# {}
# [-0.00591161  0.95365296 -0.10281443 -1.53395112]
# {}
# [ 0.01316145  1.14985222 -0.13349345 -1.85687012]
# {}
# [ 0.0361585   0.9564251  -0.17063085 -1.60844143]
# {}
# [ 0.055287    0.76368108 -0.20279968 -1.37344639]
# {}
# Episode finished after 11 timesteps
# [-0.0191079   0.00333541 -0.01806207  0.03103467]
# {}
# [-0.01904119  0.19871166 -0.01744137 -0.26729186]
# {}
# [-0.01506696  0.00384292 -0.02278721  0.01983929]
# {}
# [-0.0149901   0.19928412 -0.02239043 -0.27994527]
# {}
# [-0.01100442  0.00448861 -0.02798933  0.00559253]
# {}
# [-0.01091464  0.20000055 -0.02787748 -0.29578831]
# {}
# [-0.00691463  0.39550861 -0.03379325 -0.59713136]
# {}
# [ 0.00099554  0.20087544 -0.04573587 -0.31528161]
# {}
# [ 0.00501305  0.0064338  -0.05204151 -0.0373658 ]
# {}
# [ 0.00514172  0.20226191 -0.05278882 -0.34600359]
# {}
# [ 0.00918696  0.39809347 -0.05970889 -0.65485444]
# {}
# [ 0.01714883  0.20385144 -0.07280598 -0.38155461]
# {}
# [ 0.02122586  0.00983473 -0.08043707 -0.11268658]
# {}
# [ 0.02142256  0.20601163 -0.08269081 -0.42962348]
# {}
# [ 0.02554279  0.01215209 -0.09128328 -0.16411117]
# {}
# [ 0.02578583 -0.18155261 -0.0945655   0.09843613]
# {}
# [ 0.02215478 -0.37520098 -0.09259678  0.35985003]
# {}
# [ 0.01465076 -0.56889305 -0.08539978  0.62195889]
# {}
# [ 0.0032729  -0.76272519 -0.0729606   0.88657049]
# {}
# [-0.01198161 -0.95678494 -0.05522919  1.15545429]
# {}
# [-0.03111731 -0.76098808 -0.0321201   0.84597769]
# {}
# [-0.04633707 -0.56544298 -0.01520055  0.54336965]
# {}
# [-0.05764593 -0.76034805 -0.00433316  0.83122469]
# {}
# [-0.07285289 -0.95541051  0.01229134  1.12254169]
# {}
# [-0.0919611  -1.15069145  0.03474217  1.41905453]
# {}
# [-0.11497493 -0.9560163   0.06312326  1.13743016]
# {}
# [-0.13409525 -1.15190447  0.08587187  1.44922314]
# {}
# [-0.15713334 -1.34797064  0.11485633  1.76745403]
# {}
# [-0.18409276 -1.5441875   0.15020541  2.09353365]
# {}
# [-0.21497651 -1.35086435  0.19207608  1.85080857]
# {}
# Episode finished after 30 timesteps
# [-0.0375569  -0.02009603  0.03000293 -0.00608218]
# {}
# [-0.03795882  0.17458307  0.02988129 -0.28914988]
# {}
# [-0.03446716 -0.02095196  0.02409829  0.01280553]
# {}
# [-0.0348862   0.17381625  0.0243544  -0.27217775]
# {}
# [-0.03140988  0.36858237  0.01891085 -0.55708081]
# {}
# [-0.02403823  0.56343381  0.00776923 -0.84374624]
# {}
# [-0.01276955  0.75844888 -0.0091057  -1.13397588]
# {}
# [ 0.00239943  0.9536888  -0.03178521 -1.42950067]
# {}
# [ 0.0214732   0.75897342 -0.06037523 -1.14691841]
# {}
# [ 0.03665267  0.56468956 -0.08331359 -0.87376313]
# {}
# [ 0.04794646  0.37079319 -0.10078886 -0.60839327]
# {}
# [ 0.05536233  0.56716903 -0.11295672 -0.93104392]
# {}
# [ 0.06670571  0.37373779 -0.1315776  -0.67588483]
# {}
# [ 0.07418046  0.57041886 -0.1450953  -1.0069286 ]
# {}
# [ 0.08558884  0.37750079 -0.16523387 -0.76310072]
# {}
# [ 0.09313885  0.18499328 -0.18049588 -0.52663042]
# {}
# [ 0.09683872 -0.00719135 -0.19102849 -0.29581472]
# {}
# [ 0.09669489  0.19006752 -0.19694479 -0.64214209]
# {}
# Episode finished after 18 timesteps
# [ 0.01556782 -0.00271883  0.02806049  0.01116701]
# {}
# [ 0.01551344 -0.19823173  0.02828383  0.31256962]
# {}
# [ 0.01154881 -0.39374496  0.03453522  0.6140365 ]
# {}
# [ 0.00367391 -0.19912218  0.04681595  0.33242774]
# {}
# [-0.00030854 -0.00469677  0.05346451  0.05486803]
# {}
# [-0.00040247  0.18961944  0.05456187 -0.22047872]
# {}
# [ 0.00338992 -0.00623825  0.05015229  0.08890385]
# {}
# [ 0.00326515 -0.20204186  0.05193037  0.39697856]
# {}
# [-0.00077568 -0.39786065  0.05986994  0.70557144]
# {}
# [-0.0087329  -0.20361709  0.07398137  0.43231939]
# {}
# [-0.01280524 -0.39970431  0.08262776  0.74737635]
# {}
# [-0.02079933 -0.20581364  0.09757528  0.48179752]
# {}
# [-0.0249156  -0.40216768  0.10721123  0.80356922]
# {}
# [-0.03295895 -0.20866625  0.12328262  0.54644335]
# {}
# [-0.03713228 -0.01547243  0.13421149  0.29500539]
# {}
# [-0.03744173  0.1775063   0.14011159  0.04748026]
# {}
# [-0.0338916  -0.01931767  0.1410612   0.38088119]
# {}
# [-0.03427795 -0.21613136  0.14867882  0.714504  ]
# {}
# [-0.03860058 -0.41296449  0.1629689   1.0500471 ]
# {}
# [-0.04685987 -0.2203351   0.18396984  0.81263259]
# {}
# [-0.05126657 -0.02814516  0.2002225   0.58299498]
# {}
# Episode finished after 21 timesteps
# [ 0.0459035   0.0481358   0.03469503 -0.04529572]
# {}
# [ 0.04686622  0.24274351  0.03378911 -0.32683331]
# {}
# [ 0.05172109  0.43736851  0.02725245 -0.60867207]
# {}
# [ 0.06046846  0.63209909  0.015079   -0.89264824]
# {}
# [ 0.07311044  0.8270133  -0.00277396 -1.18055325]
# {}
# [ 0.08965071  0.63192747 -0.02638503 -0.88874118]
# {}
# [ 0.10228926  0.82739736 -0.04415985 -1.18960026]
# {}
# [ 0.1188372   1.02306295 -0.06795185 -1.4957913 ]
# {}
# [ 0.13929846  1.21894214 -0.09786768 -1.80889447]
# {}
# [ 0.1636773   1.02503835 -0.13404557 -1.54815778]
# {}
# [ 0.18417807  0.83175596 -0.16500873 -1.30012648]
# {}
# [ 0.20081319  0.63906729 -0.19101126 -1.06331215]
# {}
# Episode finished after 12 timesteps
# [ 0.02132835 -0.04179142 -0.03770092 -0.00641902]
# {}
# [ 0.02049252  0.15385036 -0.0378293  -0.31075461]
# {}
# [ 0.02356953  0.34949029 -0.04404439 -0.6151237 ]
# {}
# [ 0.03055933  0.15501051 -0.05634686 -0.33663182]
# {}
# [ 0.03365954 -0.03926619 -0.0630795  -0.06223647]
# {}
# [ 0.03287422  0.1567008  -0.06432423 -0.3741354 ]
# {}
# [ 0.03600823  0.35267468 -0.07180694 -0.68638658]
# {}
# [ 0.04306173  0.15861912 -0.08553467 -0.41714646]
# {}
# [ 0.04623411  0.3548425  -0.0938776  -0.73552202]
# {}
# [ 0.05333096  0.55112722 -0.10858804 -1.05621215]
# {}
# [ 0.0643535   0.35759873 -0.12971228 -0.79949139]
# {}
# [ 0.07150548  0.55423876 -0.14570211 -1.13000208]
# {}
# [ 0.08259025  0.75093659 -0.16830215 -1.46460759]
# {}
# [ 0.09760899  0.55822811 -0.1975943  -1.22887673]
# {}
# Episode finished after 14 timesteps
# [ 0.02435489  0.04623476  0.00577318 -0.01040876]
# {}
# [ 0.02527958 -0.14896951  0.00556501  0.28409007]
# {}
# [ 0.02230019  0.04607263  0.01124681 -0.00683251]
# {}
# [ 0.02322165  0.2410315   0.01111016 -0.29594582]
# {}
# [0.02804228 0.04575294 0.00519124 0.00022027]
# {}
# [ 0.02895734 -0.14944308  0.00519565  0.29453656]
# {}
# [0.02596847 0.04560442 0.01108638 0.00349679]
# {}
# [ 0.02688056  0.24056563  0.01115632 -0.28566774]
# {}
# [ 0.03169188  0.43552671  0.00544296 -0.57481127]
# {}
# [ 0.04040241  0.24032888 -0.00605326 -0.28041863]
# {}
# [ 0.04520899  0.0452938  -0.01166164  0.01034898]
# {}
# [ 0.04611486  0.24058103 -0.01145466 -0.2859904 ]
# {}
# [ 0.05092648  0.0456243  -0.01717446  0.00305792]
# {}
# [ 0.05183897 -0.14924719 -0.01711331  0.290273  ]
# {}
# [ 0.04885403  0.04611455 -0.01130785 -0.00775777]
# {}
# [ 0.04977632  0.24139684 -0.011463   -0.3039869 ]
# {}
# [ 0.05460425  0.04644011 -0.01754274 -0.01494107]
# {}
# [ 0.05553306  0.24180919 -0.01784156 -0.31310691]
# {}
# [ 0.06036924  0.04694589 -0.0241037  -0.02610362]
# {}
# [ 0.06130816 -0.14782225 -0.02462577  0.25887792]
# {}
# [ 0.05835171 -0.34258414 -0.01944821  0.54369294]
# {}
# [ 0.05150003 -0.14719436 -0.00857435  0.24494628]
# {}
# [ 0.04855614 -0.3421928  -0.00367543  0.53491236]
# {}
# [ 0.04171229 -0.53726288  0.00702282  0.82643492]
# {}
# [ 0.03096703 -0.34223766  0.02355152  0.53596901]
# {}
# [ 0.02412228 -0.14745465  0.0342709   0.25079903]
# {}
# [ 0.02117318  0.04716157  0.03928688 -0.03088022]
# {}
# [ 0.02211641  0.24169875  0.03866927 -0.31091345]
# {}
# [ 0.02695039  0.43624905  0.032451   -0.59115481]
# {}
# [ 0.03567537  0.24068815  0.02062791 -0.28842899]
# {}
# [0.04048913 0.04527821 0.01485933 0.01068774]
# {}
# [ 0.0413947   0.24018394  0.01507308 -0.2772701 ]
# {}
# [ 0.04619838  0.43508765  0.00952768 -0.56516112]
# {}
# [ 0.05490013  0.23983333 -0.00177554 -0.26949184]
# {}
# [ 0.0596968   0.04473676 -0.00716538  0.02263054]
# {}
# [ 0.06059153 -0.1502817  -0.00671277  0.31304412]
# {}
# [ 0.0575859   0.04493523 -0.00045189  0.01825178]
# {}
# [ 5.84846015e-02 -1.50180238e-01 -8.68495905e-05  3.10792097e-01]
# {}
# [ 0.055481   -0.34530095  0.00612899  0.60344763]
# {}
# [ 0.04857498 -0.54050809  0.01819794  0.89805475]
# {}
# [ 0.03776482 -0.34563747  0.03615904  0.61114712]
# {}
# [ 0.03085207 -0.54124566  0.04838198  0.91499605]
# {}
# [ 0.02002715 -0.34681027  0.0666819   0.63790301]
# {}
# [ 0.01309095 -0.54279558  0.07943996  0.95081759]
# {}
# [ 0.00223504 -0.34882751  0.09845632  0.68411386]
# {}
# [-0.00474151 -0.15520047  0.11213859  0.42397929]
# {}
# [-0.00784552  0.03816914  0.12061818  0.16864638]
# {}
# [-0.00708214 -0.15845429  0.12399111  0.49681446]
# {}
# [-0.01025123 -0.35508644  0.13392739  0.82585841]
# {}
# [-0.01735295 -0.55176079  0.15044456  1.15748519]
# {}
# [-0.02838817 -0.35888514  0.17359427  0.91550369]
# {}
# [-0.03556587 -0.55587572  0.19190434  1.25732927]
# {}
# Episode finished after 52 timesteps
# [-0.04018951 -0.0449472  -0.02694527 -0.00920836]
# {}
# [-0.04108846  0.15055061 -0.02712943 -0.31026958]
# {}
# [-0.03807745  0.34604837 -0.03333482 -0.61138339]
# {}
# [-0.03115648  0.1514078  -0.04556249 -0.32938336]
# {}
# [-0.02812832 -0.04303692 -0.05215016 -0.0514097 ]
# {}
# [-0.02898906 -0.23737382 -0.05317835  0.22437414]
# {}
# [-0.03373654 -0.43169699 -0.04869087  0.49981978]
# {}
# [-0.04237048 -0.23592364 -0.03869447  0.19219833]
# {}
# [-0.04708895 -0.04027013 -0.03485051 -0.1124356 ]
# {}
# [-0.04789435  0.15533342 -0.03709922 -0.41590674]
# {}
# [-0.04478768  0.35096099 -0.04541735 -0.72005084]
# {}
# [-0.03776846  0.54668091 -0.05981837 -1.0266761 ]
# {}
# [-0.02683485  0.35240413 -0.08035189 -0.75335826]
# {}
# [-0.01978676  0.54853659 -0.09541906 -1.07020576]
# {}
# [-0.00881603  0.74478189 -0.11682317 -1.39124531]
# {}
# [ 0.00607961  0.94114875 -0.14464808 -1.71805587]
# {}
# [ 0.02490258  1.13760259 -0.1790092  -2.05203757]
# {}
# Episode finished after 17 timesteps

# %%
from ray import tune
from ray.rllib.agents.ppo import PPOTrainer
